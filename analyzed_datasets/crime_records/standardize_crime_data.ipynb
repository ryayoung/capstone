# %%
import crime as cr
import pandas as pd, numpy as np
import chart_tools as ct
import plotly.express as px, seaborn as sns

# %%
cr.load('crime_16_19', full=True)
cr.load('crime_97_15', full=True)
# Out:
#                          agency_name agency_type_name  city_name  \
# 0            Lyons Police Department             City      Lyons
# 1        Kremmling Police Department             City  Kremmling
# 2        Oak Creek Police Department             City  Oak Creek
# 3             Ault Police Department             City       Ault
# 4            Romeo Police Department             City      Romeo
# ...                              ...              ...        ...
# 4952277     Gypsum Police Department             City     Gypsum
# 4952278     Gypsum Police Department             City     Gypsum
# 4952279  All Crimes Enforcement Team            Other      Viola
# 4952280  All Crimes Enforcement Team            Other      Viola
# 4952281  All Crimes Enforcement Team            Other      Viola
#
#         primary_county              offense_name crime_against  \
# 0              Boulder                       NaN           NaN
# 1                Grand                       NaN           NaN
# 2                Routt                       NaN           NaN
# 3                 Weld                       NaN           NaN
# 4              Conejos                       NaN           NaN
# ...                ...                       ...           ...
# 4952277          Eagle            Simple Assault        Person
# 4952278          Eagle     Weapon Law Violations       Society
# 4952279         Moffat  Drug/Narcotic Violations       Society
# 4952280         Moffat  Drug/Narcotic Violations       Society
# 4952281         Moffat  Drug/Narcotic Violations       Society
#
#           offense_category_name  age_num incident_date  incident_hour
# 0                           NaN      NaN           NaT            NaN
# 1                           NaN      NaN           NaT            NaN
# 2                           NaN      NaN           NaT            NaN
# 3                           NaN      NaN           NaT            NaN
# 4                           NaN      NaN           NaT            NaN
# ...                         ...      ...           ...            ...
# 4952277        Assault Offenses     44.0    2015-11-15           11.0
# 4952278   Weapon Law Violations     15.0    2015-11-22           15.0
# 4952279  Drug/Narcotic Offenses     17.0    2015-11-03           21.0
# 4952280  Drug/Narcotic Offenses     20.0    2015-11-03           21.0
# 4952281  Drug/Narcotic Offenses     17.0    2015-11-03           21.0
#
# [4952282 rows x 10 columns]

# %% [markdown]
# ### Crime 16-19

# %%
df1 = cr.df('crime_16_19')

# For put State Patrol and CBI crimes in a separate dataset
dfs1 = df1.loc[df1.pub_agency_name.isin(['State Patrol', 'Colorado Bureau of Investigation'])]

# remove them from df1
df1 = df1.loc[ ~ df1.pub_agency_name.isin(['State Patrol', 'Colorado Bureau of Investigation'])]

# Drop rows where pub agency name is null
df1 = df1[ ~ df1.pub_agency_name.isna()]

# Since we're focused on county and not police department, replace dual county
# police department county values (Ex: "JEFFERSON; ADAMS") with just the primary (Ex: "JEFFERSON")
df1.county_name = df1.county_name.str.split('; ').str[0]

# Change county name from uppercase to title case
df1.county_name = df1.county_name.str.title()

# Rename county column
df1 = df1.rename(columns={'county_name': 'county'})

# Select only needed columns
df1 = df1[['county', 'incident_date', 'incident_hour',  'age_num', 'crime_against', 'offense_name', 'offense_category_name']]

# %% [markdown]
# ### Crime 97-15

# %%
df2 = cr.df('crime_97_15')

# All the rows with null dates appear to be bullshit records and can be removed
df2 = df2[ ~ df2.incident_date.isna()]

# Put State Patrol and CBI crimes in a separate dataset, as we did for df1
dfs2 = df2.loc[df2.agency_name.isin(['State Patrol', 'Colorado Bureau of Investigation'])]

# Remove them from df2
df2 = df2.loc[ ~ df2.agency_name.isin(['State Patrol', 'Colorado Bureau of Investigation'])]

# Rename county column
df2 = df2.rename(columns={'primary_county': 'county'})

# Select only needed columns
df2 = df2[['county', 'incident_date', 'incident_hour',  'age_num', 'crime_against', 'offense_name', 'offense_category_name']]

# %%
# Save em
df1.to_csv('output/16_19.csv')
df2.to_csv('output/97_15.csv')
