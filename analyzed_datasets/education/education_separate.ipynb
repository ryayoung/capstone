# %%
import pandas as pd
grad = pd.read_csv('output/dist_grad_rate.csv', index_col=0)
mobi = pd.read_csv('output/dist_mobility_rate.csv', index_col=0)

# %% [markdown]
# ## Mobility Rate
# ---

# %% [markdown]
# **TOTALS**

# %%
df = mobi.copy()
df = df[[
    'county',
    'school_dist',
    'school_dist_code',
    'total_pupil_count_all_students',
    'total_stable_pupil_count_all_students',
    'total_stability_rate_all_students',
    'total_mobile_student_count_all_students',
    'total_student_mobility_rate_all_students',
    'total_instances_of_mobility_all_students',
    'total_mobility_incidence_rate_all_students',
]]
df.columns = [
    'county',
    'school_dist',
    'school_dist_code',
    'pupil_count',
    'stable_pupil_count',
    'stability_rate',
    'mobile_student_count',
    'student_mobility_rate',
    'instances_of_mobility',
    'mobility_incidence_rate',
]
df.to_csv('output/dist_mobility_rate/totals.csv')
df
# Out:
#             county                 school_dist  school_dist_code  pupil_count  \
# 0      STATE TOTAL                 STATE TOTAL            9999.0     939283.0
# 1      STATE TOTAL                 STATE TOTAL            9999.0     939283.0
# 2            ADAMS                  MAPLETON 1              10.0       9037.0
# 3            ADAMS  ADAMS 12 FIVE STAR SCHOOLS              20.0      49889.0
# 4            ADAMS             ADAMS COUNTY 14              30.0       8265.0
# ..             ...                         ...               ...          ...
# 180         DENVER    CHARTER SCHOOL INSTITUTE            8001.0      12020.0
# 181  COLORADO BOCS              MOUNTAIN BOCES            9030.0        184.0
# 182  COLORADO BOCS            CENTENNIAL BOCES            9035.0        146.0
# 183  COLORADO BOCS              SAN JUAN BOCES            9050.0         84.0
# 184  COLORADO BOCS         EXPEDITIONARY BOCES            9130.0        402.0
#
# ...

# %% [markdown]
# **STUDENTS WITH DISABILITIES**

# %%
df = mobi.copy()
df = df[[
    'county',
    'school_dist',
    'school_dist_code',
    'students_with_disabilities_pupil_count',
    'students_with_disabilities_stable_student_count',
    'students_with_disabilities_stability_rate',
    'students_with_disabilities_mobile_student_count',
    'students_with_disabilities_student_mobility_rate',
    'students_with_disabilities_instances_of_mobility',
    'students_with_disabilities_mobility_incidence_rate',
]]
df.columns = [
    'county',
    'school_dist',
    'school_dist_code',
    'pupil_count',
    'stable_student_count',
    'stability_rate',
    'mobile_student_count',
    'student_mobility_rate',
    'instances_of_mobility',
    'mobility_incidence_rate',

]
df.to_csv('output/dist_mobility_rate/students_with_disabilities.csv')
df
# Out:
#             county                 school_dist  school_dist_code  pupil_count  \
# 0      STATE TOTAL                 STATE TOTAL            9999.0      84121.0
# 1      STATE TOTAL                 STATE TOTAL            9999.0      84121.0
# 2            ADAMS                  MAPLETON 1              10.0        735.0
# 3            ADAMS  ADAMS 12 FIVE STAR SCHOOLS              20.0       4339.0
# 4            ADAMS             ADAMS COUNTY 14              30.0        876.0
# ..             ...                         ...               ...          ...
# 180         DENVER    CHARTER SCHOOL INSTITUTE            8001.0        708.0
# 181  COLORADO BOCS              MOUNTAIN BOCES            9030.0         36.0
# 182  COLORADO BOCS            CENTENNIAL BOCES            9035.0          2.0
# 183  COLORADO BOCS              SAN JUAN BOCES            9050.0          5.0
# 184  COLORADO BOCS         EXPEDITIONARY BOCES            9130.0         40.0
#
# ...

# %% [markdown]
# **English language learners**

# %%
df = mobi.copy()
df = df[[
    'county',
    'school_dist',
    'school_dist_code',
    'english_language_learners_pupil_count',
    'english_language_learners_stable_student_count',
    'english_language_learners_stability_rate',
    'english_language_learners_mobile_student_count',
    'english_language_learners_student_mobility_rate',
    'english_language_learners_instances_of_mobility',
    'english_language_learners_mobility_incidence_rate',
]]
df.columns = [
    'county',
    'school_dist',
    'school_dist_code',
    'pupil_count',
    'stable_student_count',
    'stability_rate',
    'mobile_student_count',
    'student_mobility_rate',
    'instances_of_mobility',
    'mobility_incidence_rate',

]
df.to_csv('output/dist_mobility_rate/english_language_learners.csv')
df
# Out:
#             county                 school_dist  school_dist_code  pupil_count  \
# 0      STATE TOTAL                 STATE TOTAL            9999.0     135712.0
# 1      STATE TOTAL                 STATE TOTAL            9999.0     135712.0
# 2            ADAMS                  MAPLETON 1              10.0       2863.0
# 3            ADAMS  ADAMS 12 FIVE STAR SCHOOLS              20.0       6141.0
# 4            ADAMS             ADAMS COUNTY 14              30.0       3826.0
# ..             ...                         ...               ...          ...
# 180         DENVER    CHARTER SCHOOL INSTITUTE            8001.0       2067.0
# 181  COLORADO BOCS              MOUNTAIN BOCES            9030.0         11.0
# 182  COLORADO BOCS            CENTENNIAL BOCES            9035.0          8.0
# 183  COLORADO BOCS              SAN JUAN BOCES            9050.0          0.0
# 184  COLORADO BOCS         EXPEDITIONARY BOCES            9130.0         16.0
#
# ...

# %% [markdown]
# **Economically disadvantaged**

# %%
df = mobi.copy()
df = df[[
    'county',
    'school_dist',
    'school_dist_code',
    'economically_disadvantaged_pupil_count',
    'economically_disadvantaged_stable_student_count',
    'economically_disadvantaged_stability_rate',
    'economically_disadvantaged_mobile_student_count',
    'economically_disadvantaged_student_mobility_rate',
    'economically_disadvantaged_instances_of_mobility',
    'economically_disadvantaged_mobility_incidence_rate',
]]
df.columns = [
    'county',
    'school_dist',
    'school_dist_code',
    'pupil_count',
    'stable_student_count',
    'stability_rate',
    'mobile_student_count',
    'student_mobility_rate',
    'instances_of_mobility',
    'mobility_incidence_rate',
]
df.to_csv('output/dist_mobility_rate/economically_disadvantaged.csv')
df
# Out:
#             county                 school_dist  school_dist_code  pupil_count  \
# 0      STATE TOTAL                 STATE TOTAL            9999.0     369904.0
# 1      STATE TOTAL                 STATE TOTAL            9999.0     369904.0
# 2            ADAMS                  MAPLETON 1              10.0       2729.0
# 3            ADAMS  ADAMS 12 FIVE STAR SCHOOLS              20.0      18560.0
# 4            ADAMS             ADAMS COUNTY 14              30.0       6657.0
# ..             ...                         ...               ...          ...
# 180         DENVER    CHARTER SCHOOL INSTITUTE            8001.0       5764.0
# 181  COLORADO BOCS              MOUNTAIN BOCES            9030.0        127.0
# 182  COLORADO BOCS            CENTENNIAL BOCES            9035.0          0.0
# 183  COLORADO BOCS              SAN JUAN BOCES            9050.0          0.0
# 184  COLORADO BOCS         EXPEDITIONARY BOCES            9130.0         37.0
#
# ...

# %% [markdown]
# **Migrant**

# %%
df = mobi.copy()
df = df[[
    'county',
    'school_dist',
    'school_dist_code',
    'migrant_pupil_count',
    'migrant_stable_student_count',
    'migrant_stability_rate',
    'migrant_mobile_student_count',
    'migrant_student_mobility_rate',
    'migrant_instances_of_mobility',
    'migrant_mobility_incidence_rate',
]]
df.columns = [
    'county',
    'school_dist',
    'school_dist_code',
    'pupil_count',
    'stable_student_count',
    'stability_rate',
    'mobile_student_count',
    'student_mobility_rate',
    'instances_of_mobility',
    'mobility_incidence_rate',
]
df.to_csv('output/dist_mobility_rate/migrant.csv')
df
# Out:
#             county                 school_dist  school_dist_code  pupil_count  \
# 0      STATE TOTAL                 STATE TOTAL            9999.0       2732.0
# 1      STATE TOTAL                 STATE TOTAL            9999.0       2732.0
# 2            ADAMS                  MAPLETON 1              10.0         32.0
# 3            ADAMS  ADAMS 12 FIVE STAR SCHOOLS              20.0         93.0
# 4            ADAMS             ADAMS COUNTY 14              30.0         54.0
# ..             ...                         ...               ...          ...
# 180         DENVER    CHARTER SCHOOL INSTITUTE            8001.0          5.0
# 181  COLORADO BOCS              MOUNTAIN BOCES            9030.0          0.0
# 182  COLORADO BOCS            CENTENNIAL BOCES            9035.0          0.0
# 183  COLORADO BOCS              SAN JUAN BOCES            9050.0          0.0
# 184  COLORADO BOCS         EXPEDITIONARY BOCES            9130.0          0.0
#
# ...

# %% [markdown]
# **Title 1**

# %%
df = mobi.copy()
df = df[[
    'county',
    'school_dist',
    'school_dist_code',
    'title_1_pupil_count',
    'title_1_stable_student_count',
    'title_1_pupil_stability_rate',
    'title_1_mobile_student_count',
    'title_1_student_mobility_rate',
    'title_1_instances_of_mobility',
    'title_1_mobility_incidence_rate',
]]
df.columns = [
    'county',
    'school_dist',
    'school_dist_code',
    'pupil_count',
    'stable_student_count',
    'pupil_stability_rate',
    'mobile_student_count',
    'student_mobility_rate',
    'instances_of_mobility',
    'mobility_incidence_rate',
]
df.to_csv('output/dist_mobility_rate/title_1.csv')
df
# Out:
#             county                 school_dist  school_dist_code  pupil_count  \
# 0      STATE TOTAL                 STATE TOTAL            9999.0     223008.0
# 1      STATE TOTAL                 STATE TOTAL            9999.0     223008.0
# 2            ADAMS                  MAPLETON 1              10.0       4045.0
# 3            ADAMS  ADAMS 12 FIVE STAR SCHOOLS              20.0       8571.0
# 4            ADAMS             ADAMS COUNTY 14              30.0       5555.0
# ..             ...                         ...               ...          ...
# 180         DENVER    CHARTER SCHOOL INSTITUTE            8001.0       6594.0
# 181  COLORADO BOCS              MOUNTAIN BOCES            9030.0          0.0
# 182  COLORADO BOCS            CENTENNIAL BOCES            9035.0          0.0
# 183  COLORADO BOCS              SAN JUAN BOCES            9050.0          0.0
# 184  COLORADO BOCS         EXPEDITIONARY BOCES            9130.0          0.0
#
# ...

# %% [markdown]
# **Homeless**

# %%
df = mobi.copy()
df = df[[
    'county',
    'school_dist',
    'school_dist_code',
    'homeless_pupil_count',
    'homeless_stable_student_count',
    'homeless_stability_rate',
    'homeless_mobile_student_count',
    'homeless_student_mobility_rate',
    'homeless_instances_of_mobility',
    'homeless_mobility_incidence_rate',
]]
df.columns = [
    'county',
    'school_dist',
    'school_dist_code',
    'pupil_count',
    'stable_student_count',
    'stability_rate',
    'mobile_student_count',
    'student_mobility_rate',
    'instances_of_mobility',
    'mobility_incidence_rate',
]
df.to_csv('output/dist_mobility_rate/homeless.csv')
df
# Out:
#             county                 school_dist  school_dist_code  pupil_count  \
# 0      STATE TOTAL                 STATE TOTAL            9999.0      21337.0
# 1      STATE TOTAL                 STATE TOTAL            9999.0      21337.0
# 2            ADAMS                  MAPLETON 1              10.0        214.0
# 3            ADAMS  ADAMS 12 FIVE STAR SCHOOLS              20.0        705.0
# 4            ADAMS             ADAMS COUNTY 14              30.0        886.0
# ..             ...                         ...               ...          ...
# 180         DENVER    CHARTER SCHOOL INSTITUTE            8001.0         94.0
# 181  COLORADO BOCS              MOUNTAIN BOCES            9030.0         35.0
# 182  COLORADO BOCS            CENTENNIAL BOCES            9035.0          0.0
# 183  COLORADO BOCS              SAN JUAN BOCES            9050.0          0.0
# 184  COLORADO BOCS         EXPEDITIONARY BOCES            9130.0          1.0
#
# ...

# %% [markdown]
# **Gifted Talented**

# %%
df = mobi.copy()
df = df[[
    'county',
    'school_dist',
    'school_dist_code',
    'gifted_talented_pupil_count',
    'gifted_talented_stable_student_count',
    'gifted_talented_stability_rate',
    'gifted_talented_mobile_student_count',
    'gifted_talented_student_mobility_rate',
    'gifted_talented_instances_of_mobility',
    'gifted_talented_mobility_incidence_rate',
]]
df.columns = [
    'county',
    'school_dist',
    'school_dist_code',
    'pupil_count',
    'stable_student_count',
    'stability_rate',
    'mobile_student_count',
    'student_mobility_rate',
    'instances_of_mobility',
    'mobility_incidence_rate',
]
df.to_csv('output/dist_mobility_rate/gifted_talented.csv')
df
# Out:
#             county                 school_dist  school_dist_code  pupil_count  \
# 0      STATE TOTAL                 STATE TOTAL            9999.0      73344.0
# 1      STATE TOTAL                 STATE TOTAL            9999.0      73344.0
# 2            ADAMS                  MAPLETON 1              10.0        250.0
# 3            ADAMS  ADAMS 12 FIVE STAR SCHOOLS              20.0       3590.0
# 4            ADAMS             ADAMS COUNTY 14              30.0        377.0
# ..             ...                         ...               ...          ...
# 180         DENVER    CHARTER SCHOOL INSTITUTE            8001.0        343.0
# 181  COLORADO BOCS              MOUNTAIN BOCES            9030.0          1.0
# 182  COLORADO BOCS            CENTENNIAL BOCES            9035.0          0.0
# 183  COLORADO BOCS              SAN JUAN BOCES            9050.0          3.0
# 184  COLORADO BOCS         EXPEDITIONARY BOCES            9130.0          0.0
#
# ...

# %% [markdown]
# # Grad Rate
# ---

# %% [markdown]
# **Students with disabilities**

# %%
df = grad.copy()
df = df[[
    'county',
    'school_dist',
    'school_dist_code',
    'students_with_disabilities_final_grad_base',
    'students_with_disabilities_graduates_total',
    'students_with_disabilities_graduation_rate',
    'students_with_disabilities_completers_total',
    'students_with_disabilities_completion_rate',
]]
df.columns = [
    'county',
    'school_dist',
    'school_dist_code',
    'final_grad_base',
    'graduates_total',
    'graduation_rate',
    'completers_total',
    'completion_rate',
]
df.to_csv('output/dist_grad_rate/students_with_disabilities.csv')
df
# Out:
#             county                 school_dist  school_dist_code  \
# 0      STATE TOTAL                 STATE TOTAL            9999.0
# 1      STATE TOTAL                 STATE TOTAL            9999.0
# 2            ADAMS                  MAPLETON 1              10.0
# 3            ADAMS  ADAMS 12 FIVE STAR SCHOOLS              20.0
# 4            ADAMS             ADAMS COUNTY 14              30.0
# ..             ...                         ...               ...
# 182  COLORADO BOCS            CENTENNIAL BOCES            9035.0
# 183  COLORADO BOCS              SAN JUAN BOCES            9050.0
# 184  COLORADO BOCS         EXPEDITIONARY BOCES            9130.0
# 185    STATE TOTAL                 STATE TOTAL            9999.0
# 186    STATE TOTAL                 STATE TOTAL            9999.0
#
#      final_grad_base  graduates_total  graduation_rate  completers_total  \
# 0             5775.0           3099.0             53.7            3222.0
# ...

# %% [markdown]
# **English language learners**

# %%
df = grad.copy()
df = df[[
    'county',
    'school_dist',
    'school_dist_code',
    'limited_english_proficient_final_grad_base',
    'limited_english_proficient_graduates_total',
    'limited_english_proficient_graduation_rate',
    'limited_english_proficient_completers_total',
    'limited_english_proficient_completion_rate',
]]
df.columns = [
    'county',
    'school_dist',
    'school_dist_code',
    'final_grad_base',
    'graduates_total',
    'graduation_rate',
    'completers_total',
    'completion_rate',
]
df.to_csv('output/dist_grad_rate/english_language_learners.csv')
df
# Out:
#             county                 school_dist  school_dist_code  \
# 0      STATE TOTAL                 STATE TOTAL            9999.0
# 1      STATE TOTAL                 STATE TOTAL            9999.0
# 2            ADAMS                  MAPLETON 1              10.0
# 3            ADAMS  ADAMS 12 FIVE STAR SCHOOLS              20.0
# 4            ADAMS             ADAMS COUNTY 14              30.0
# ..             ...                         ...               ...
# 182  COLORADO BOCS            CENTENNIAL BOCES            9035.0
# 183  COLORADO BOCS              SAN JUAN BOCES            9050.0
# 184  COLORADO BOCS         EXPEDITIONARY BOCES            9130.0
# 185    STATE TOTAL                 STATE TOTAL            9999.0
# 186    STATE TOTAL                 STATE TOTAL            9999.0
#
#      final_grad_base  graduates_total  graduation_rate  completers_total  \
# 0             6171.0           3289.0             53.3            3364.0
# ...

# %% [markdown]
# **Economically disadvantaged**

# %%
df = grad.copy()
df = df[[
    'county',
    'school_dist',
    'school_dist_code',
    'econ_disadvant_final_grad_base',
    'econ_disadvant_graduates_total',
    'econ_disadvant_graduation_rate',
    'econ_disadvant_completers_total',
    'econ_disadvant_completion_rate',
]]
df.columns = [
    'county',
    'school_dist',
    'school_dist_code',
    'final_grad_base',
    'graduates_total',
    'graduation_rate',
    'completers_total',
    'completion_rate',
]
df.to_csv('output/dist_grad_rate/economically_disadvantaged.csv')
df
# Out:
#             county                 school_dist  school_dist_code  \
# 0      STATE TOTAL                 STATE TOTAL            9999.0
# 1      STATE TOTAL                 STATE TOTAL            9999.0
# 2            ADAMS                  MAPLETON 1              10.0
# 3            ADAMS  ADAMS 12 FIVE STAR SCHOOLS              20.0
# 4            ADAMS             ADAMS COUNTY 14              30.0
# ..             ...                         ...               ...
# 182  COLORADO BOCS            CENTENNIAL BOCES            9035.0
# 183  COLORADO BOCS              SAN JUAN BOCES            9050.0
# 184  COLORADO BOCS         EXPEDITIONARY BOCES            9130.0
# 185    STATE TOTAL                 STATE TOTAL            9999.0
# 186    STATE TOTAL                 STATE TOTAL            9999.0
#
#      final_grad_base  graduates_total  graduation_rate  completers_total  \
# 0            25718.0          15791.0             61.4           16726.0
# ...

# %% [markdown]
# **Migrant**

# %%
df = grad.copy()
df = df[[
    'county',
    'school_dist',
    'school_dist_code',
    'migrant_final_grad_base',
    'migrant_graduates_total',
    'migrant_graduation_rate',
    'migrant_completers_total',
    'migrant_completion_rate',
]]
df.columns = [
    'county',
    'school_dist',
    'school_dist_code',
    'final_grad_base',
    'graduates_total',
    'graduation_rate',
    'completers_total',
    'completion_rate',
]
df.to_csv('output/dist_grad_rate/migrant.csv')
df
# Out:
#             county                 school_dist  school_dist_code  \
# 0      STATE TOTAL                 STATE TOTAL            9999.0
# 1      STATE TOTAL                 STATE TOTAL            9999.0
# 2            ADAMS                  MAPLETON 1              10.0
# 3            ADAMS  ADAMS 12 FIVE STAR SCHOOLS              20.0
# 4            ADAMS             ADAMS COUNTY 14              30.0
# ..             ...                         ...               ...
# 182  COLORADO BOCS            CENTENNIAL BOCES            9035.0
# 183  COLORADO BOCS              SAN JUAN BOCES            9050.0
# 184  COLORADO BOCS         EXPEDITIONARY BOCES            9130.0
# 185    STATE TOTAL                 STATE TOTAL            9999.0
# 186    STATE TOTAL                 STATE TOTAL            9999.0
#
#      final_grad_base  graduates_total  graduation_rate  completers_total  \
# 0              384.0            214.0             55.7             223.0
# ...

# %% [markdown]
# **Title 1**

# %%
df = grad.copy()
df = df[[
    'county',
    'school_dist',
    'school_dist_code',
    'title_1_final_grad_base',
    'title_1_graduates_total',
    'title_1_graduation_rate',
    'title_1_completers_total',
    'title_1_completion_rate',
]]
df.columns = [
    'county',
    'school_dist',
    'school_dist_code',
    'final_grad_base',
    'graduates_total',
    'graduation_rate',
    'completers_total',
    'completion_rate',
]
df.to_csv('output/dist_grad_rate/title_1.csv')
df
# Out:
#             county                 school_dist  school_dist_code  \
# 0      STATE TOTAL                 STATE TOTAL            9999.0
# 1      STATE TOTAL                 STATE TOTAL            9999.0
# 2            ADAMS                  MAPLETON 1              10.0
# 3            ADAMS  ADAMS 12 FIVE STAR SCHOOLS              20.0
# 4            ADAMS             ADAMS COUNTY 14              30.0
# ..             ...                         ...               ...
# 182  COLORADO BOCS            CENTENNIAL BOCES            9035.0
# 183  COLORADO BOCS              SAN JUAN BOCES            9050.0
# 184  COLORADO BOCS         EXPEDITIONARY BOCES            9130.0
# 185    STATE TOTAL                 STATE TOTAL            9999.0
# 186    STATE TOTAL                 STATE TOTAL            9999.0
#
#      final_grad_base  graduates_total  graduation_rate  completers_total  \
# 0             7398.0           3853.0             52.1            4129.0
# ...

# %% [markdown]
# **Homeless**

# %%
df = grad.copy()
df = df[[
    'county',
    'school_dist',
    'school_dist_code',
    'homeless_final_grad_base',
    'homeless_graduates_total',
    'homeless_graduation_rate',
    'homeless_completers_total',
    'homeless_completion_rate',
]]
df.columns = [
    'county',
    'school_dist',
    'school_dist_code',
    'final_grad_base',
    'graduates_total',
    'graduation_rate',
    'completers_total',
    'completion_rate',
]
df.to_csv('output/dist_grad_rate/homeless.csv')
df
# Out:
#             county                 school_dist  school_dist_code  \
# 0      STATE TOTAL                 STATE TOTAL            9999.0
# 1      STATE TOTAL                 STATE TOTAL            9999.0
# 2            ADAMS                  MAPLETON 1              10.0
# 3            ADAMS  ADAMS 12 FIVE STAR SCHOOLS              20.0
# 4            ADAMS             ADAMS COUNTY 14              30.0
# ..             ...                         ...               ...
# 182  COLORADO BOCS            CENTENNIAL BOCES            9035.0
# 183  COLORADO BOCS              SAN JUAN BOCES            9050.0
# 184  COLORADO BOCS         EXPEDITIONARY BOCES            9130.0
# 185    STATE TOTAL                 STATE TOTAL            9999.0
# 186    STATE TOTAL                 STATE TOTAL            9999.0
#
#      final_grad_base  graduates_total  graduation_rate  completers_total  \
# 0             2394.0           1175.0             49.1            1262.0
# ...

# %% [markdown]
# **Gifted Talented**

# %%
df = grad.copy()
df = df[[
    'county',
    'school_dist',
    'school_dist_code',
    'gifted_talented_final_grad_base',
    'gifted_talented_graduates_total',
    'gifted_talented_graduation_rate',
    'gifted_talented_completers_total',
    'gifted_talented_completion_rate',
]]
df.columns = [
    'county',
    'school_dist',
    'school_dist_code',
    'final_grad_base',
    'graduates_total',
    'graduation_rate',
    'completers_total',
    'completion_rate',
]
df.to_csv('output/dist_grad_rate/gifted_talented.csv')
df
# Out:
#             county                 school_dist  school_dist_code  \
# 0      STATE TOTAL                 STATE TOTAL            9999.0
# 1      STATE TOTAL                 STATE TOTAL            9999.0
# 2            ADAMS                  MAPLETON 1              10.0
# 3            ADAMS  ADAMS 12 FIVE STAR SCHOOLS              20.0
# 4            ADAMS             ADAMS COUNTY 14              30.0
# ..             ...                         ...               ...
# 182  COLORADO BOCS            CENTENNIAL BOCES            9035.0
# 183  COLORADO BOCS              SAN JUAN BOCES            9050.0
# 184  COLORADO BOCS         EXPEDITIONARY BOCES            9130.0
# 185    STATE TOTAL                 STATE TOTAL            9999.0
# 186    STATE TOTAL                 STATE TOTAL            9999.0
#
#      final_grad_base  graduates_total  graduation_rate  completers_total  \
# 0             6604.0           6048.0             91.6            6156.0
# ...
